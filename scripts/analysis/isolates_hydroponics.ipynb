# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import h5py

# %%
f = h5py.File("/Users/glmarschmann/.julia/dev/DEBmicroTrait/final_manuscript/files/isolates_hydroponics.jld", "r")
tseries = f["solt"].value
useries = f["solu"].value
rel0 = f["rel0"].value
rel3 = f["rel3"].value
E = f["E"].value
D = f["D"].value
V = f["V"].value

# %%
isolates = np.arange(0,36)

# %%
fig_width = 9.28                         # inches  
golden_mean = (np.sqrt(5)-1.0)/2.0      # Aesthetic ratio
fig_height = fig_width*golden_mean      # height in inches
dpi = 300.0                             # Convert inch to pt

# Margins are specified as a fraction of axes size.
# May need to adjust (especially left and bottom) to accomodate axes labels/tickmarks
leftmargin = 0.15
bottommargin = 0.2
rightmargin = 0.05
topmargin = 0.1
# These two parameters are used for adjusting spacing between subplots (when used)
wspace = 0.2
hspace = 0.2

fig_size =  [fig_width,fig_height]
params = {'backend': 'svg',
          'axes.labelsize': 8,
          'axes.titlesize': 10,
          'legend.fontsize': 8,
          'xtick.labelsize': 8,
          'ytick.labelsize': 8,
          'figure.figsize': fig_size}

# %%
plt.rcParams.update(params)
plt.figure(1)
plt.clf()
plt.axes([leftmargin,
            bottommargin,
            1.0 - rightmargin-leftmargin,
            1.0 - topmargin-bottommargin])

# %%
plt.plot(isolates, rel3, "D", mec="k", color='#d95f02', ms=10, label="Week 0")
plt.plot(isolates, rel0, "D", mec="k", color='#1b9e77', ms=10, label="Week 3")
plt.xticks(np.arange(0, 36, step=1))
plt.grid("on")
plt.legend()
plt.ylabel("Relative abundance [-]")
plt.xlabel("Isolate")
plt.savefig("/Users/glmarschmann/.julia/dev/DEBmicroTrait/final_manuscript/plots/isolates_hydroponics_relative_abundance.svg", format="svg")

# %%
fig_width = 6.28                         # inches  
golden_mean = (np.sqrt(5)-1.0)/2.0      # Aesthetic ratio
fig_height = 2.5      # height in inches
dpi = 300.0                             # Convert inch to pt

# Margins are specified as a fraction of axes size.
# May need to adjust (especially left and bottom) to accomodate axes labels/tickmarks
leftmargin = 0.15
bottommargin = 0.2
rightmargin = 0.05
topmargin = 0.1
# These two parameters are used for adjusting spacing between subplots (when used)
wspace = 0.2
hspace = 0.2

fig_size =  [fig_width,fig_height]
params = {'backend': 'ps',
          'axes.labelsize': 8,
          'axes.titlesize': 10,
          'legend.fontsize': 8,
          'xtick.labelsize': 8,
          'ytick.labelsize': 8,
          'figure.figsize': fig_size}

# %%
plt.rcParams.update(params)
plt.figure(1)
plt.clf()
plt.axes([leftmargin,
            bottommargin,
            1.0 - rightmargin-leftmargin,
            1.0 - topmargin-bottommargin])

# %%
plt.plot(tseries/24, D, c="g", label="2-aminoisobutyric acid")
plt.xlabel("Time [d]")
plt.ylabel("Exudate concentration [mM]")
plt.legend()
plt.savefig("/Users/glmarschmann/.julia/dev/DEBmicroTrait/final_manuscript/plots/isolates_hydroponics_D.png", dpi=300)

# %%
plt.plot(tseries/24, E, c="k", label="Bacillus sp. URHB0009")
plt.xlabel("Time [d]")
plt.ylabel("Reserve biomass [mM]")
plt.legend()
plt.savefig("/Users/glmarschmann/.julia/dev/DEBmicroTrait/final_manuscript/plots/isolates_hydroponics_E.png", dpi=300)

# %%
plt.plot(tseries/24, V, c="k", label="Bacillus sp. URHB0009")
plt.xlabel("Time [d]")
plt.ylabel("Structural biomass [mM]")
plt.legend()
plt.savefig("/Users/glmarschmann/.julia/dev/DEBmicroTrait/final_manuscript/plots/isolates_hydroponics_V.png", dpi=300)

# %%
plt.plot(tseries, negseries, color='k')
plt.plot(tseries, posseries, color='g')

# %%
f = h5py.File("/Users/glmarschmann/.julia/dev/DEBmicroTrait/final_manuscript/files/isolates_hydroponics_delta_biomass.jld", "r")
dnorm = f["Deltabionorm"].value

# %%
dnorm.shape
# Out:
# (5, 27)

# %%
dnormpos = dnorm[:,0:18]
dnormneg = dnorm[:,19:27]

# %%
fig_width = 6.28                         # inches  
golden_mean = (np.sqrt(5)-1.0)/2.0      # Aesthetic ratio
fig_height = fig_width*golden_mean      # height in inches
dpi = 300.0                             # Convert inch to pt

# Margins are specified as a fraction of axes size.
# May need to adjust (especially left and bottom) to accomodate axes labels/tickmarks
leftmargin = 0.15
bottommargin = 0.2
rightmargin = 0.05
topmargin = 0.1
# These two parameters are used for adjusting spacing between subplots (when used)
wspace = 0.2
hspace = 0.2

fig_size =  [fig_width,fig_height]
params = {'backend': 'svg',
          'axes.labelsize': 8,
          'axes.titlesize': 10,
          'legend.fontsize': 8,
          'xtick.labelsize': 8,
          'ytick.labelsize': 8,
          'figure.figsize': fig_size}

# %%
plt.rcParams.update(params)
plt.figure(1)
plt.clf()
plt.axes([leftmargin,
            bottommargin,
            1.0 - rightmargin-leftmargin,
            1.0 - topmargin-bottommargin])

# %%
plt.plot(np.arange(0,18), dnormpos[1,:], "D", mec="k", color='#d95f02', ms=10, label="")
plt.plot(np.arange(0,18), dnormpos[2,:], "D", mec="k", color='#7570b3', ms=10, label="")
plt.plot(np.arange(0,18), dnormpos[3,:], "D", mec="k", color='#e7298a', ms=10, label="")
plt.plot(np.arange(0,18), dnormpos[4,:], "D", mec="k", color='#66a61e', ms=10, label="")
plt.plot(np.arange(19,27), dnormneg[1,:], "D", mec="k", color='#d95f02', ms=10, label="Week 3")
plt.plot(np.arange(19,27), dnormneg[2,:], "D", mec="k", color='#7570b3', ms=10, label="Week 6")
plt.plot(np.arange(19,27), dnormneg[3,:], "D", mec="k", color='#e7298a', ms=10, label="Week 9")
plt.plot(np.arange(19,27), dnormneg[4,:], "D", mec="k", color='#66a61e', ms=10, label="Week 12")
plt.xticks(np.arange(0, 27, step=1))
plt.grid("on")
plt.legend(bbox_to_anchor=(1,1), loc="upper left")
plt.ylabel("Normalized change in relative abundance [-]")
plt.xlabel("")
plt.ylim(-0.2,1.1)
plt.savefig("/Users/glmarschmann/.julia/dev/DEBmicroTrait/final_manuscript/plots/isolates_hydroponics_norm_delta_relative_abundance.svg", format="svg")

# %%
f = h5py.File("/Users/glmarschmann/.julia/dev/DEBmicroTrait/final_manuscript/files/isolates_hydroponics_tseries.jld", "r")
tseries = f["tseries"].value
posseries = f["tseriesp"].value
negseries = f["tseriesn"].value
posseriesE = f["tseriespE"].value
negseriesE = f["tseriesnE"].value
Sugarseries = f["Sugarseries"].value
Organicseries = f["Organicseries"].value
Aminoseries = f["Aminoseries"].value
Fattyseries = f["Fattyseries"].value
Nucleoseries = f["Nucleoseries"].value
Auxinseries = f["Auxinseries"].value

# %%
negseries.shape
# Out:
# (2995, 8)

# %%
fig_width = 6.28                         # inches  
golden_mean = (np.sqrt(5)-1.0)/2.0      # Aesthetic ratio
fig_height = fig_width*golden_mean      # height in inches
dpi = 300.0                             # Convert inch to pt

# Margins are specified as a fraction of axes size.
# May need to adjust (especially left and bottom) to accomodate axes labels/tickmarks
leftmargin = 0.15
bottommargin = 0.2
rightmargin = 0.05
topmargin = 0.1
# These two parameters are used for adjusting spacing between subplots (when used)
wspace = 0.2
hspace = 0.2

fig_size =  [fig_width,fig_height]
params = {'backend': 'svg',
          'axes.labelsize': 8,
          'axes.titlesize': 10,
          'legend.fontsize': 8,
          'xtick.labelsize': 8,
          'ytick.labelsize': 8,
          'figure.figsize': fig_size}

# %%
plt.rcParams.update(params)
plt.figure(1)
plt.clf()
plt.axes([leftmargin,
            bottommargin,
            1.0 - rightmargin-leftmargin,
            1.0 - topmargin-bottommargin])

# %%
plt.plot(tseries/24/7, posseries[:,13], color='#007100', label="positive")
plt.plot(tseries/24/7, negseries, color='#bd5e8b', label="negative")
plt.xlabel("Time [weeks]")
plt.ylabel(r"Structural biomass [mM]")
plt.yscale('log')
plt.legend()
#plt.ticklabel_format(axis='y', style='sci',scilimits=(-4,4))
plt.xticks([0,3,6,9,12])
#plt.savefig("/Users/glmarschmann/.julia/dev/DEBmicroTrait/final_manuscript/plots/isolates_hydroponics_biomass.svg", format="svg")
# Out:
# ([<matplotlib.axis.XTick at 0x7feb248c8f60>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
fig_width = 6.28                         # inches  
golden_mean = (np.sqrt(5)-1.0)/2.0      # Aesthetic ratio
fig_height = fig_width*golden_mean      # height in inches
dpi = 300.0                             # Convert inch to pt

# Margins are specified as a fraction of axes size.
# May need to adjust (especially left and bottom) to accomodate axes labels/tickmarks
leftmargin = 0.15
bottommargin = 0.2
rightmargin = 0.05
topmargin = 0.1
# These two parameters are used for adjusting spacing between subplots (when used)
wspace = 0.2
hspace = 0.2

fig_size =  [fig_width,fig_height]
params = {'backend': 'svg',
          'axes.labelsize': 8,
          'axes.titlesize': 10,
          'legend.fontsize': 8,
          'xtick.labelsize': 8,
          'ytick.labelsize': 8,
          'figure.figsize': fig_size}

# %%
plt.rcParams.update(params)
plt.figure(1)
plt.clf()
plt.axes([leftmargin,
            bottommargin,
            1.0 - rightmargin-leftmargin,
            1.0 - topmargin-bottommargin])

# %%
plt.plot(tseries/24/7, Sugarseries*1e6, color='#1b9e77', label = "Sugar")
plt.plot(tseries/24/7, Organicseries*1e6, color='#d95f02', label = "Organic acid")
plt.plot(tseries/24/7, Aminoseries*1e6, color='#7570b3', label = "Amino acid")
plt.plot(tseries/24/7, Fattyseries*1e6, color='#e7298a', label = "Fatty acid")
plt.plot(tseries/24/7, Nucleoseries*1e6, color='#66a61e', label = "Nucleotide")
plt.plot(tseries/24/7, Auxinseries*1e6, color='#e6ab02', label = "Auxin")
plt.xlabel("Time [weeks]")
plt.ylabel(r"Exudate concentration [$\mu$M]")
plt.legend()
#plt.yscale('log')
plt.ticklabel_format(axis='y', style='sci',scilimits=(-4,4))
plt.xticks([0,3,6,9,12])
plt.savefig("/Users/glmarschmann/.julia/dev/DEBmicroTrait/final_manuscript/plots/isolates_hydroponics_exudates.png", dpi=300)

# %%
f = h5py.File("/Users/glmarschmann/.julia/dev/DEBmicroTrait/final_manuscript/files/isolates_hydroponics_tseries_BGE.jld", "r")
BGEposseries = f["tseriesBGEpos"].value
BGEnegseries = f["tseriesBGEneg"].value
BGEnegseries.shape
ts = np.arange(0,2995)

# %%
fig_width = 6.28                         # inches  
golden_mean = (np.sqrt(5)-1.0)/2.0      # Aesthetic ratio
fig_height = fig_width*golden_mean      # height in inches
dpi = 300.0                             # Convert inch to pt

# Margins are specified as a fraction of axes size.
# May need to adjust (especially left and bottom) to accomodate axes labels/tickmarks
leftmargin = 0.15
bottommargin = 0.2
rightmargin = 0.05
topmargin = 0.1
# These two parameters are used for adjusting spacing between subplots (when used)
wspace = 0.2
hspace = 0.2

fig_size =  [fig_width,fig_height]
params = {'backend': 'ps',
          'axes.labelsize': 8,
          'axes.titlesize': 10,
          'legend.fontsize': 8,
          'xtick.labelsize': 8,
          'ytick.labelsize': 8,
          'figure.figsize': fig_size}

# %%
plt.rcParams.update(params)
plt.figure(1)
plt.clf()
plt.axes([leftmargin,
            bottommargin,
            1.0 - rightmargin-leftmargin,
            1.0 - topmargin-bottommargin])

# %%
plt.plot(ts[0:7*24*12]/24/7, BGEposseries[0:7*24*12,13],  color='#007100', label="Pseudomonas sp. URHB0015")
plt.plot(ts[0:7*24*12]/24/7, BGEnegseries[0:7*24*12,5],  color='#bd5e8b', label="Paenibacillus sp. URHA0014")
plt.xticks([0,3,6,9,12])
plt.xlabel("Time [weeks]")
plt.ylabel("Carbon use efficiency [-]")
plt.legend()
plt.savefig("/Users/glmarschmann/.julia/dev/DEBmicroTrait/final_manuscript/plots/isolates_hydroponics_BGE_select.png", dpi=300)
